# %%
import os
import numpy as np
import json
import librosa
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils import resample
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings("ignore")

# ========== Feature Extraction with Additional Features ==========
def extract_features_and_label(base_path):
    try:
        pitch_file = base_path + ".pitch.txt"
        tonic_file = base_path + ".ctonic.txt"
        json_file = base_path + ".json"

        if not all(os.path.exists(f) for f in [pitch_file, tonic_file, json_file]):
            print(f"Missing required file(s) for {base_path}. Skipping...")
            return None, None

        # Load pitch data
        pitch_data = np.loadtxt(pitch_file)
        if pitch_data.shape[0] == 0:  # Empty pitch data
            print(f"Empty pitch data for {base_path}. Skipping...")
            return None, None
        
        freqs = pitch_data[:, 1]
        freqs = np.where(freqs == 0, np.nan, freqs)

        # Load tonic value
        with open(tonic_file) as f:
            tonic = f.read().strip()
        
        if not tonic or tonic == '0':  # Check for missing or invalid tonic
            print(f"Invalid tonic data for {base_path}. Skipping...")
            return None, None
        
        tonic = float(tonic)

        # Normalize pitch data
        norm_pitch = 1200 * np.log2(freqs / tonic)
        norm_pitch = norm_pitch[~np.isnan(norm_pitch)]

        # If pitch data is too short, skip this file
        if len(norm_pitch) < 100:
            print(f"Insufficient pitch data for {base_path}. Skipping...")
            return None, None

        # Create histogram of normalized pitch values
        hist, _ = np.histogram(norm_pitch, bins=60, range=(-600, 1200), density=True)

        # Extract MFCCs
        y, sr = librosa.load(base_path + ".wav", sr=None)
        mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
        mfccs_mean = np.mean(mfccs, axis=1)

        # Combine histogram and MFCC features
        features = np.concatenate((hist, mfccs_mean))
        
        # Load raga label from metadata
        with open(json_file) as f:
            meta = json.load(f)

        raga = meta.get("raaga", [{}])[0].get("name")
        return features, raga if raga else (None, None)

    except Exception as e:
        print(f"Error in feature extraction: {e}")
        return None, None


# ========== Dataset Loader with Balanced Sampling ==========
def load_data_from_directory(data_dir):
    X, y = [], []
    for root, dirs, files in os.walk(data_dir):
        for file in files:
            if file.endswith(".json"):
                base_name = os.path.splitext(file)[0]
                base_path = os.path.join(root, base_name)
                features, label = extract_features_and_label(base_path)
                if features is not None:
                    X.append(features)
                    y.append(label)

    X, y = np.array(X), np.array(y)

    # Handle class imbalance (oversample minor classes like 'Kamās')
    X_resampled, y_resampled = resample(X, y, replace=True, n_samples=2000, random_state=42)
    
    return X_resampled, y_resampled

# ========== Hyperparameter Tuning Using GridSearch ==========
def train_model(X, y):
    clf = RandomForestClassifier(random_state=42)
    
    param_grid = {
        'n_estimators': [100, 200, 300],
        'max_depth': [10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    }

    grid_search = GridSearchCV(clf, param_grid, cv=5, n_jobs=-1)
    grid_search.fit(X, y)
    
    print(f"Best Hyperparameters: {grid_search.best_params_}")
    return grid_search.best_estimator_

# ========== Predict from Audio ==========
def predict_raga_from_audio(audio_path, clf):
    try:
        y, sr = librosa.load(audio_path, sr=None)

        # Better pitch extraction using YIN
        pitch_values = librosa.yin(y, fmin=librosa.note_to_hz('C2'), 
                                   fmax=librosa.note_to_hz('C7'), sr=sr)
        pitch_values = pitch_values[~np.isnan(pitch_values)]

        if len(pitch_values) < 100:
            print("⚠️ Audio too short or unclear for prediction.")
            return

        # Estimate tonic using histogram mode
        tonic_hist, tonic_bins = np.histogram(np.log2(pitch_values), bins=100)
        tonic_guess = 2 ** tonic_bins[np.argmax(tonic_hist)]

        norm_pitch = 1200 * np.log2(pitch_values / tonic_guess)
        hist, _ = np.histogram(norm_pitch, bins=60, range=(-600, 1200), density=True)

        # Extract MFCCs
        mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
        mfccs_mean = np.mean(mfccs, axis=1)

        # Combine histogram and MFCC features
        features = np.concatenate((hist, mfccs_mean))

        # Predict
        probs = clf.predict_proba([features])[0]
        top_indices = np.argsort(probs)[-3:][::-1]
        labels = clf.classes_

        print("\n🎧 Top 3 Raga Predictions:")
        for i in top_indices:
            predicted_raga = labels[i]
            print(f"→ {predicted_raga}: {probs[i]*100:.1f}%")

    except Exception as e:
        print(f"❌ Error processing audio: {e}")

# ========== Main ==========
DATA_DIR = "D:/carnatic/carnatic"  # Path to Saraga Carnatic folder
X, y = load_data_from_directory(DATA_DIR)

if len(X) > 0:
    # Train the model with hyperparameter tuning
    clf = train_model(X, y)

    # Ask user for audio file path
    audio_path = input("🎵 Enter path to your audio file (.mp3 or .wav): ").strip()
    if os.path.exists(audio_path):
        predict_raga_from_audio(audio_path, clf)
    else:
        print("❌ File not found. Please check the path.")
else:
    print("❌ Model training failed. Check dataset path and files.")
# Out:
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\0\\Cherthala Ranganatha Sharma - Varashiki Vahana.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\1\\Cherthala Ranganatha Sharma - Bhuvini Dasudane.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\10\\Sanjay Subrahmanyan - Pullum Silambena Kan.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\100\\Modhumudi Sudhakar - Telisi Rama.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\101\\Modhumudi Sudhakar - Sundari Nee Divya.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\102\\Modhumudi Sudhakar - Rama Namam Bhajare.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\103\\Modhumudi Sudhakar - Ghandhamu Poyyaruga.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\104\\Modhumudi Sudhakar - Mangalam Avanisutanatha.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\105\\Mahati - Sharanagatha Vatsale.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\106\\Mahati - Hiranmayeem.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\107\\Mahati - Kannallavo Swami.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\108\\Mahati - Padavini.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\109\\Mahati - Ragam Tanam Pallavi.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\11\\Sanjay Subrahmanyan - Ennadu Jootuno.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\110\\Mahati - Vandu Ketpaar Illayo.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\111\\Mahati - Gopi Gopala Bala.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\112\\Mahati - Chinnanchiru Kiliye.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\113\\Mahati - Tillana.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\114\\Mahati - Pavamana Suttudu Pattu.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\115\\Kanakadurga Venkatesh - Rama Neepai.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\116\\Kanakadurga Venkatesh - Etulabrotuva.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\117\\Kanakadurga Venkatesh - Lokavana Chatura.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\118\\Kanakadurga Venkatesh - Neevada Negana.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\119\\Kanakadurga Venkatesh - Enthavedukonthu Raghava.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\12\\Sanjay Subrahmanyan - Aru marundu.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\120\\Kanakadurga Venkatesh - Koluvamaregatha.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\121\\Kanakadurga Venkatesh - Vara Leela Gana Lola.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\122\\Srividya Janakiraman - Sarasuda Ninne Kori.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\123\\Srividya Janakiraman - Jaya Jaya Janaki Kantha.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\124\\Srividya Janakiraman - Santhamu leka Sowkyamu ledu.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\125\\Srividya Janakiraman - Sri Dundurge Siva Samsaare.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\126\\Srividya Janakiraman - Gnanamosaga Rada.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\127\\Srividya Janakiraman - Parvathi Ninu Ne Nera Nammithi.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\128\\Srividya Janakiraman - Nee Sari evvaramma.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\129\\Srividya Janakiraman - Nenindal Agaadadu undo.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\13\\Sanjay Subrahmanyan - Sri Raghuvara Sugunaalaya.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\130\\Sumithra Vasudev - Vanajaksha Ninne Kori.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\131\\Sumithra Vasudev - Sri Vidhya Rajagopala.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\132\\Sumithra Vasudev - Karuninchutakidi.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\133\\Sumithra Vasudev - Ramabhi Rama Manasu.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\134\\Sumithra Vasudev - Thoomani Madatthu.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\135\\Sumithra Vasudev - Sri Guru Na Palitosmi.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\136\\Sumithra Vasudev - Mati Matiki.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\137\\Sumithra Vasudev - Aaniraimekkani.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\138\\Sumithra Vasudev - Va Va Brindavana.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\139\\Sumithra Vasudev - Mangalam Kosalendraya.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\14\\Sanjay Subrahmanyan - Sarasadalanayana.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\140\\Chaitra Sairam - Rakta Ganapatim.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\141\\Chaitra Sairam - Ardhanareeshwaram.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\142\\Chaitra Sairam - Kamalamba Samrakshatu.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\143\\Chaitra Sairam - Anandaamrutakarshini.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\144\\Chaitra Sairam - Govardhana Girisham.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\145\\Chaitra Sairam - Shri Subramanyaya Namaste.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\146\\Chaitra Sairam - Gange Maampahi.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\147\\Chaitra Sairam - Mamava Pattabhi Rama.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\148\\Kuldeep Pai - Kari Kalabha Mukham.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\149\\Kuldeep Pai - Kaalaharanamelara.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\15\\Sanjay Subrahmanyan - Paarengum.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\150\\Kuldeep Pai - Brochevarevarura.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\151\\Kuldeep Pai - Arul Seya Vendum Ayya.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\152\\Kuldeep Pai - Gange Maam Pahi.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\153\\Kuldeep Pai - Thappi Bratikipova.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\154\\Kuldeep Pai - Vasudeva Sutam Devam.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\155\\Kuldeep Pai - Krishna Nee Begane Baaro.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\156\\Sanjay Subrahmanyan - Undan Paada Pankayam.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\157\\Sanjay Subrahmanyan - Shatre Vilagi Irum.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\158\\Sanjay Subrahmanyan - Kamakshi.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\159\\Sanjay Subrahmanyan - Entara Nitana.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\16\\Sanjay Subrahmanyan - Ragam Thanam Pallavi - Shanmukhapriya.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\160\\Sanjay Subrahmanyan - Soundararajam.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\161\\Sanjay Subrahmanyan - Ozhukkam Uyirinum.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\162\\Sanjay Subrahmanyan - Raagam Thaanam Pallavi.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\163\\Sanjay Subrahmanyan - Maname Ramanai Paada.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\164\\Sanjay Subrahmanyan - Teerthakarayinile.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\165\\Sanjay Subrahmanyan - Payum Oli Nee Yenakku.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\166\\Sanjay Subrahmanyan - Thillana Dhanashri.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\167\\Sanjay Subrahmanyan - Pavamana Suthudu.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\168\\Ashwath Narayanan - Sadabalarupapi Shlokam.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\169\\Ashwath Narayanan - Eranapai.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\17\\Sanjay Subrahmanyan - Saravanabhava Enum.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\170\\Ashwath Narayanan - Samajavarada.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\171\\Ashwath Narayanan - Aparadhamula.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\172\\Ashwath Narayanan - Angakaram.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\173\\Ashwath Narayanan - Parama Purusham.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\174\\Ashwath Narayanan - Evarura.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\175\\Ashwath Narayanan - Marubari.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\176\\Ashwath Narayanan - Thillana Purnachandrika.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\177\\Vignesh Ishwar - Evvari Bodhana.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\178\\Vignesh Ishwar - Karuna Ela Gante.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\179\\Vignesh Ishwar - Lokavana Chatura.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\18\\Sanjay Subrahmanyan - Karuvutranaal Mudalaaga.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\180\\Vignesh Ishwar - Hiranmayeem Lakshmeem.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\181\\Vignesh Ishwar - Gopanandana.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\182\\Vignesh Ishwar - Amba Kamakshi.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\183\\Vignesh Ishwar - Sanchara Dhadhara.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\184\\Vignesh Ishwar - Idhuthaano Thillai Sthalam.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\185\\Vignesh Ishwar - Vitthala Salaho Swamy.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\186\\Vignesh Ishwar - Niraimadi Mugam Thiruppugazh.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\187\\Vignesh Ishwar - Pavamana Suthudu Mangalam.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\188\\V. Shankaranarayanan - Shloka.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\189\\V. Shankaranarayanan - Nera Nammiti.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\19\\Sanjay Subrahmanyan - Maname Kanamum.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\190\\V. Shankaranarayanan - Ninne Bhajana.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\191\\V. Shankaranarayanan - Dinamani Vamsa.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\192\\V. Shankaranarayanan - Ardhanareeshwaram.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\193\\V. Shankaranarayanan - Chakkani Raja.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\194\\V. Shankaranarayanan - Chenduril Nindradum Kanda.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\195\\V. Shankaranarayanan - Muruga Muruga Muruga.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\196\\V. Shankaranarayanan - Pavamana Suthudu Pattu.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\2\\Cherthala Ranganatha Sharma - Velum Mayilume.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\20\\Sanjay Subrahmanyan - Pavamaana Suthudu Pattu.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\21\\Sanjay Subrahmanyan - Vanajakshi - Varnam.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\22\\Sanjay Subrahmanyan - Sama geeta priyan.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\23\\Sanjay Subrahmanyan - Nadopasana.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\24\\Sanjay Subrahmanyan - Janani.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\25\\Sanjay Subrahmanyan - Deenarakshaka.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\26\\Sanjay Subrahmanyan - Va vela va.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\27\\Sanjay Subrahmanyan - Chalamelara Saketha Rama.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\28\\Sanjay Subrahmanyan - O Rangashayee.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\29\\Sanjay Subrahmanyan - Ganta mani aadudhu.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\3\\Cherthala Ranganatha Sharma - Karuna Nidhi Illalo.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\30\\Sanjay Subrahmanyan - Uppum karpuramum.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\31\\Sanjay Subrahmanyan - Innamum Oru thalam.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\32\\Sanjay Subrahmanyan - Oorilen Kaani Illai.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\33\\Sanjay Subrahmanyan - Karupuram Naarumo.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\34\\Sanjay Subrahmanyan - Ramakrishnaru Manaegae.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\35\\Sanjay Subrahmanyan - Teerthakarayinile.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\36\\Sanjay Subrahmanyan - Ninnaiye rathi.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\37\\Sanjay Subrahmanyan - Kalilo Hari Smrana.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\38\\Sanjay Subrahmanyan - Mangalam.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\39\\KP Nandini - Nadatanum Anisham.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\4\\Cherthala Ranganatha Sharma - Tulasi Bilva.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\40\\Rithvik Raja - Karunimpa Idi.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\41\\Rithvik Raja - Endaro Mahanubhavulu.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\42\\S Sundar - Vanajaksha Ninne Nammiti.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\43\\S Sundar - Parvathi Ninnu Neranammiti.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\44\\KP Nandini - Ardhanarishwaram.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\45\\KP Nandini - Bhavamulona.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\46\\KP Nandini - Manasaramathi.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\47\\KP Nandini - Seethamma.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\48\\KP Nandini - Janakipathe Jaya Karunya Jaladhe.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\49\\KP Nandini - Eppadi Padinaro.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\5\\Cherthala Ranganatha Sharma - Rama Rama Guna Seema.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\50\\KP Nandini - Tillana.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\51\\S Sundar - Nannu Brova Neeku.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\52\\S Sundar - Paahi Maam Sri.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\53\\S Sundar - Eppadi Manam Thunindhadho.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\54\\S Sundar - Sudhaamayee.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\55\\S Sundar - Jaya Jaya Padmanabhanujese.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\56\\S Sundar - Enadhu Manam Kavalai.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\57\\S Sundar - Purahara Nandana.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\58\\S Sundar - Geetha Vaadya Natana.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\59\\S Sundar - Shloka Namaste Sarvalokana.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\6\\Cherthala Ranganatha Sharma - Prathi Vaaram Vaaram.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\60\\S Sundar - Nera Nammiti.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\61\\S Sundar - Kannanai Paadu Maname.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\62\\S Sundar - Devadi Devanukku Jaya Mangalam.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\63\\Rithvik Raja - Chintayama Kanda.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\64\\Rithvik Raja - Seetapati Namanasuna.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\65\\Rithvik Raja - Emani Migula.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\66\\Rithvik Raja - Bhogeendra Shayinam.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\67\\Rithvik Raja - Saraguna Palimpa.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\68\\Rithvik Raja - Madhava Mamava.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\69\\Rithvik Raja - Sapasyat Kausalya.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\7\\Cherthala Ranganatha Sharma - Idhu Thaano Thillai Sthalam.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\70\\Rithvik Raja - Thillana Senchurutti.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\71\\Rithvik Raja - Ramachandraya Mangalam.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\72\\Vasundara Rajagopal - Sri Jalandara.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\73\\Vasundara Rajagopal - Chandrashekharam Sada Bhajeham.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\74\\Vasundara Rajagopal - Ninnuvina Marigalada.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\75\\Vasundara Rajagopal - Pranamamyaham Sri Prananatham.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\76\\Vasundara Rajagopal - Amba Nilambari.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\77\\Vasundara Rajagopal - Munnu Ravana.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\78\\Vasundara Rajagopal - Shlokham.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\79\\Vasundara Rajagopal - Ni Ninaindhal Aagadhadhu.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\8\\Cherthala Ranganatha Sharma - Shlokam - Shivah Shaktyayukto.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\80\\Vasundara Rajagopal - Avani Sutha.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\81\\Akkarai Sisters - Karunimpa Idi.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\82\\Akkarai Sisters - Siddhi Vinayakam.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\83\\Akkarai Sisters - Koti Janmani.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\84\\Akkarai Sisters - Apparama Bhakti.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\85\\Akkarai Sisters - Brova Barama.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\86\\Akkarai Sisters - Shankari Shankuru.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\87\\Akkarai Sisters - Geeta Nayakan.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\88\\Akkarai Sisters - Manadirkkugandhadu.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\89\\Akkarai Sisters - Thillana Pahadi.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\9\\Sanjay Subrahmanyan - Eranapai.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\90\\Akkarai Sisters - Pavamana Suthudu Mangalam.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\91\\Modhumudi Sudhakar - Giriraja Suta.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\92\\Modhumudi Sudhakar - Dudukugala.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\93\\Modhumudi Sudhakar - Edari Sancharintura.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\94\\Modhumudi Sudhakar - Shobillu Saptasvara.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\95\\Modhumudi Sudhakar - Paramatmudu.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\96\\Modhumudi Sudhakar - Paraloka Bhaya.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\97\\Modhumudi Sudhakar - Entha Muddo.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\98\\Modhumudi Sudhakar - Koluvaiyunnade.wav'
# Error in feature extraction: [Errno 2] No such file or directory: 'D:/carnatic/carnatic\\99\\Modhumudi Sudhakar - Eramuni.wav'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 155
#     153 # ========== Main ==========
#     154 DATA_DIR = "D:/carnatic/carnatic"  # Path to Saraga Carnatic folder
# --> 155 X, y = load_data_from_directory(DATA_DIR)
#     157 if len(X) > 0:
#     158     # Train the model with hyperparameter tuning
#     159     clf = train_model(X, y)
#
# Cell In[1], line 91, in load_data_from_directory(data_dir)
#      88 X, y = np.array(X), np.array(y)
#      90 # Handle class imbalance (oversample minor classes like 'Kamās')
# ---> 91 X_resampled, y_resampled = resample(X, y, replace=True, n_samples=2000, random_state=42)
#      93 return X_resampled, y_resampled
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_indexing.py:523, in resample(replace, n_samples, random_state, stratify, *arrays)
#     521 if stratify is None:
#     522     if replace:
# --> 523         indices = random_state.randint(0, n_samples, size=(max_n_samples,))
#     524     else:
#     525         indices = np.arange(n_samples)
#
# File numpy\\random\\mtrand.pyx:780, in numpy.random.mtrand.RandomState.randint()
#
# File numpy\\random\\_bounded_integers.pyx:1425, in numpy.random._bounded_integers._rand_int32()
#
# ValueError: high <= 0

# %%
import os
import numpy as np
import json
import librosa
from collections import Counter
from sklearn.ensemble import RandomForestClassifier
import warnings

warnings.filterwarnings("ignore")

# ——— 1. FEATURE EXTRACTION ———
def extract_features_and_label(base_path):
    pitch_file = base_path + ".pitch.txt"
    tonic_file = base_path + ".ctonic.txt"
    meta_file  = base_path + ".json"

    # must have all three
    if not (os.path.isfile(pitch_file) and os.path.isfile(tonic_file) and os.path.isfile(meta_file)):
        return None, None

    # load pitch
    try:
        data = np.loadtxt(pitch_file)
    except:
        return None, None
    if data.ndim != 2 or data.shape[0] < 2:
        return None, None

    freqs = data[:,1]
    freqs = freqs[freqs>0]

    # load tonic
    try:
        with open(tonic_file) as f:
            tonic = float(f.read().strip())
    except:
        return None, None

    # normalize to cents
    cents = 1200 * np.log2(freqs / tonic)
    if len(cents) < 100:
        return None, None

    # histogram → 60‑dim feature
    hist, _ = np.histogram(cents, bins=60, range=(-600,1200), density=True)

    # load raga label
    try:
        with open(meta_file) as f:
            meta = json.load(f)
        label = meta["raaga"][0]["name"]
    except:
        return None, None

    return hist, label

# ——— 2. LOAD TRAINING DATA ———
def load_dataset(root_dir):
    X, y = [], []
    for rd, _, files in os.walk(root_dir):
        for fn in files:
            if fn.lower().endswith(".json"):
                base = os.path.join(rd, fn[:-5])
                feat, lbl = extract_features_and_label(base)
                if feat is not None:
                    X.append(feat); y.append(lbl)
    return np.array(X), np.array(y)

DATA_DIR = "D:/carnatic/carnatic"
X, y = load_dataset(DATA_DIR)
print("✅ Samples:", len(X))
print("🎵 Unique ragas:", len(set(y)))
print("🎯 Counts:", Counter(y))

# ——— 3. TRAIN MODEL ———
clf = RandomForestClassifier(
    n_estimators=200,
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)
clf.fit(X, y)

# ——— 4. RAGA DESCRIPTIONS ———
raga_descriptions = {
    "Kamās":      "A gentle, sweet raga—often devotional, expressing longing.",
    "Kalyāṇi":    "A bright, devotional Melakarta raga, evoking auspiciousness.",
    "Tōḍi":       "Deeply emotional Melakarta raga, performed in early morning.",
    "Gaula":      "A meditative janya raga with a calm, devotional character.",
    # … add all your ragas here …
}

# ——— 5. PREDICTION FROM MP3/WAV ———
def predict_raga(audio_path):
    y_audio, sr = librosa.load(audio_path, sr=None)
    pitches = librosa.yin(
        y_audio,
        fmin=librosa.note_to_hz("C2"),
        fmax=librosa.note_to_hz("C7"),
        sr=sr
    )
    pitches = pitches[~np.isnan(pitches)]
    if len(pitches) < 100:
        print("⚠️ Audio too short or noisy for reliable pitch extraction.")
        return

    # tonic estimation
    h, bins = np.histogram(np.log2(pitches), bins=100)
    tonic = 2 ** bins[np.argmax(h)]

    cents = 1200 * np.log2(pitches / tonic)
    hist, _ = np.histogram(cents, bins=60, range=(-600,1200), density=True)

    # pad/truncate to 60
    if len(hist) < 60:
        hist = np.pad(hist, (0, 60-len(hist)), 'constant')
    else:
        hist = hist[:60]

    pred = clf.predict([hist])[0]
    print(f"\n🎧 Predicted Raga: {pred}")
    print("📖", raga_descriptions.get(pred, "Description not available."))

# ——— 6. RUN ———
path = input("🎵 Enter path to your audio file (.mp3 or .wav): ").strip()
if os.path.isfile(path):
    predict_raga(path)
else:
    print("❌ File not found. Please check the path and try again.")
# Out:
# ✅ Samples: 184
# 🎵 Unique ragas: 96
# 🎯 Counts: Counter({'Rāgamālika': 8, 'Saurāṣtraṁ': 7, 'Tōḍi': 7, 'Kamās': 7, 'Bhairavi': 5, 'Behāg': 5, 'Kalyāṇi': 4, 'Suraṭi': 4, 'Ṣanmukhapriya': 4, 'Rītigauḷa': 4, 'Mōhanaṁ': 4, 'Śankarābharaṇaṁ': 3, 'Bēgaḍa': 3, 'Kāṁbhōji': 3, 'Sāvēri': 3, 'Jōnpuri': 3, 'Sindhubhairavi': 3, 'Harikāmbhōji': 3, 'Kānaḍa': 3, 'Śrīranjani': 2, 'Pūrṇacandrika': 2, 'Madhyamāvati': 2, 'Nādanāmakriya': 2, 'Lalita': 2, 'Nāṭa': 2, 'Kalgaḍa': 2, 'Jaganmōhini': 2, 'Hamīr kaḷyaṇi': 2, 'Pāḍi': 2, 'Amṛtavarṣiṇi': 2, 'Maṇirangu': 2, 'Śuddadhanyāsi': 2, 'Kuntalavarāḷi': 2, 'Kāpi': 2, 'Ābhōgi': 2, 'Karṇāṭaka dēvagāndhāri': 2, 'Kumudakriyā': 2, 'Karaharapriya': 2, 'Gauḷa': 2, 'Mārgahindōḷaṁ': 2, 'Kēdāragauḷa': 2, 'Sahānā': 2, 'Nīlāṁbari': 2, 'Puṇṇāgavarāḷi': 1, 'Kathanakutūhalaṁ': 1, 'Sālaga bhairavi': 1, 'Kalāvati': 1, 'Dvijāvanti': 1, 'Kedāraṁ': 1, 'Cakravākaṁ': 1, 'Sāranga': 1, 'Sarasvatī manōhari': 1, 'Sāma': 1, 'Gamakakriyā': 1, 'Sindhumandāri': 1, 'Dhanyāsi': 1, 'Ānandabhairavi': 1, 'Hindōḷaṁ': 1, 'Rasikapriya': 1, 'Yamuna kalyāṇi': 1, 'Pūrvīkaḷyāṇi': 1, 'Bṛndāvana sāranga': 1, 'Dhanaśrī': 1, 'Hamsadhvani': 1, 'Śudda sāvēri': 1, 'Latāngi': 1, 'Lalita pancamaṁ': 1, 'Varāḷi': 1, 'Bhūṣāvaḷi': 1, 'Dēś': 1, 'Haṁsānandi': 1, 'Mānḍu': 1, 'Sucaritra': 1, 'Āhiri': 1, 'Tanarūpi': 1, 'Tillāng': 1, 'Bāgēśrī': 1, 'Cittaranjani': 1, 'Śrī': 1, 'Sārāmati': 1, 'Vasanta': 1, 'Simhēndra madhyamaṁ': 1, 'Janaranjani': 1, 'Hussēnī': 1, 'Nāṭakapriya': 1, 'Sencuruṭṭi': 1, 'Navrōj': 1, 'Gaṁbhīra nāṭa': 1, 'Ranjani': 1, 'Kāmavardani/Pantuvarāḷi': 1, 'Bahudāri': 1, 'Pahāḍi': 1, 'Vāgadīśvari': 1, 'Mandāri': 1, 'Dēvagāndhāri': 1, 'Vakuḷābharaṇaṁ': 1})
# 🎵 Enter path to your audio file (.mp3 or .wav):  D:\carnatic\carnatic\33\Sanjay Subrahmanyan - Karupuram Naarumo.mp3
# 🎧 Predicted Raga: Kalyāṇi
# 📖 A bright, devotional Melakarta raga, evoking auspiciousness.

# %%
import os
import numpy as np
import json
import librosa
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from collections import Counter
import warnings

warnings.filterwarnings("ignore")

# ——— 1) FEATURE EXTRACTION (60‑bin histogram only) ———
def extract_hist(base_path):
    p_file   = base_path + ".pitch.txt"
    t_file   = base_path + ".ctonic.txt"
    j_file   = base_path + ".json"
    if not all(os.path.isfile(f) for f in (p_file, t_file, j_file)):
        return None, None

    # load pitch
    try:
        data = np.loadtxt(p_file)
        freqs = data[:,1]
        freqs = freqs[freqs > 0]
    except:
        return None, None

    # load tonic
    try:
        tonic = float(open(t_file).read().strip())
    except:
        return None, None

    # cents
    cents = 1200 * np.log2(freqs/tonic)
    cents = cents[~np.isnan(cents)]
    if len(cents) < 100:
        return None, None

    # 60‑bin histogram
    hist, _ = np.histogram(cents, bins=60, range=(-600,1200), density=True)

    # label
    try:
        meta = json.load(open(j_file))
        label = meta["raaga"][0]["name"]
    except:
        return None, None

    return hist, label

# ——— 2) LOAD TRAINING DATA ———
def load_data(root_dir):
    X, y = [], []
    for rd, _, files in os.walk(root_dir):
        for fn in files:
            if fn.lower().endswith(".json"):
                base = os.path.join(rd, fn[:-5])
                hist, lbl = extract_hist(base)
                if hist is not None:
                    X.append(hist); y.append(lbl)
    X = np.array(X)
    y = np.array(y)
    print(f"🔍 After loading: X.shape = {X.shape}, y.shape = {y.shape}")
    print("📊 Raga distribution:", Counter(y))
    return X, y

DATA_DIR = "D:/carnatic/carnatic"
X, y = load_data(DATA_DIR)

if len(X)==0:
    print("❌ No training data—please check your pitch/tonic/json files.")
    raise SystemExit

# ——— 3) STANDARDIZE ———
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
print("✅ Scaled training data shape:", X_scaled.shape)

# ——— 4) TRAIN MODEL ———
clf = RandomForestClassifier(n_estimators=200, class_weight='balanced', random_state=42, n_jobs=-1)
clf.fit(X_scaled, y)
print("🏆 Model trained on histogram features.")

# ——— 5) PREDICTION FUNCTION ———
# ——— 5) PREDICTION FUNCTION (Top‑3) ———
def predict_raga(audio_path):
    # 5a) pitch track
    y_audio, sr = librosa.load(audio_path, sr=None)
    pitches = librosa.yin(y_audio,
                          fmin=librosa.note_to_hz("C2"),
                          fmax=librosa.note_to_hz("C7"),
                          sr=sr)
    pitches = pitches[~np.isnan(pitches)]
    if len(pitches) < 100:
        print("⚠️ Audio too short or noisy.")
        return

    # 5b) estimate tonic, compute cents, hist
    h, bins = np.histogram(np.log2(pitches), bins=100)
    tonic = 2 ** bins[np.argmax(h)]
    cents = 1200 * np.log2(pitches/tonic)
    hist, _ = np.histogram(cents, bins=60, range=(-600,1200), density=True)

    # 5c) reshape to 2D
    feat2d = hist.reshape(1, -1)

    # 5d) scale & get probabilities
    feat_scaled = scaler.transform(feat2d)
    probs = clf.predict_proba(feat_scaled)[0]

    # 5e) top‑3
    idxs = np.argsort(probs)[-3:][::-1]
    print("\n🎧 Top 3 Raga Predictions:")
    for i in idxs:
        print(f"→ {clf.classes_[i]}: {probs[i]*100:.1f}%")

# ——— 5) PREDICTION FUNCTION (Top‑3) ———
def predict_raga(audio_path):
    # 5a) pitch track
    y_audio, sr = librosa.load(audio_path, sr=None)
    pitches = librosa.yin(y_audio,
                          fmin=librosa.note_to_hz("C2"),
                          fmax=librosa.note_to_hz("C7"),
                          sr=sr)
    pitches = pitches[~np.isnan(pitches)]
    if len(pitches) < 100:
        print("⚠️ Audio too short or noisy.")
        return

    # 5b) estimate tonic, compute cents, hist
    h, bins = np.histogram(np.log2(pitches), bins=100)
    tonic = 2 ** bins[np.argmax(h)]
    cents = 1200 * np.log2(pitches/tonic)
    hist, _ = np.histogram(cents, bins=60, range=(-600,1200), density=True)

    # 5c) reshape to 2D
    feat2d = hist.reshape(1, -1)

    # 5d) scale & get probabilities
    feat_scaled = scaler.transform(feat2d)
    probs = clf.predict_proba(feat_scaled)[0]

    # 5e) top‑3
    idxs = np.argsort(probs)[-3:][::-1]
    print("\n🎧 Top 3 Raga Predictions:")
    for i in idxs:
        print(f"→ {clf.classes_[i]}: {probs[i]*100:.1f}%")

# ——— 6) RUN ———
audio_path = input("🎵 Enter your .mp3/.wav path: ").strip()
if os.path.isfile(audio_path):
    predict_raga(audio_path)
else:
    print("❌ File not found.")
# Out:
# 🔍 After loading: X.shape = (184, 60), y.shape = (184,)
# 📊 Raga distribution: Counter({'Rāgamālika': 8, 'Saurāṣtraṁ': 7, 'Tōḍi': 7, 'Kamās': 7, 'Bhairavi': 5, 'Behāg': 5, 'Kalyāṇi': 4, 'Suraṭi': 4, 'Ṣanmukhapriya': 4, 'Rītigauḷa': 4, 'Mōhanaṁ': 4, 'Śankarābharaṇaṁ': 3, 'Bēgaḍa': 3, 'Kāṁbhōji': 3, 'Sāvēri': 3, 'Jōnpuri': 3, 'Sindhubhairavi': 3, 'Harikāmbhōji': 3, 'Kānaḍa': 3, 'Śrīranjani': 2, 'Pūrṇacandrika': 2, 'Madhyamāvati': 2, 'Nādanāmakriya': 2, 'Lalita': 2, 'Nāṭa': 2, 'Kalgaḍa': 2, 'Jaganmōhini': 2, 'Hamīr kaḷyaṇi': 2, 'Pāḍi': 2, 'Amṛtavarṣiṇi': 2, 'Maṇirangu': 2, 'Śuddadhanyāsi': 2, 'Kuntalavarāḷi': 2, 'Kāpi': 2, 'Ābhōgi': 2, 'Karṇāṭaka dēvagāndhāri': 2, 'Kumudakriyā': 2, 'Karaharapriya': 2, 'Gauḷa': 2, 'Mārgahindōḷaṁ': 2, 'Kēdāragauḷa': 2, 'Sahānā': 2, 'Nīlāṁbari': 2, 'Puṇṇāgavarāḷi': 1, 'Kathanakutūhalaṁ': 1, 'Sālaga bhairavi': 1, 'Kalāvati': 1, 'Dvijāvanti': 1, 'Kedāraṁ': 1, 'Cakravākaṁ': 1, 'Sāranga': 1, 'Sarasvatī manōhari': 1, 'Sāma': 1, 'Gamakakriyā': 1, 'Sindhumandāri': 1, 'Dhanyāsi': 1, 'Ānandabhairavi': 1, 'Hindōḷaṁ': 1, 'Rasikapriya': 1, 'Yamuna kalyāṇi': 1, 'Pūrvīkaḷyāṇi': 1, 'Bṛndāvana sāranga': 1, 'Dhanaśrī': 1, 'Hamsadhvani': 1, 'Śudda sāvēri': 1, 'Latāngi': 1, 'Lalita pancamaṁ': 1, 'Varāḷi': 1, 'Bhūṣāvaḷi': 1, 'Dēś': 1, 'Haṁsānandi': 1, 'Mānḍu': 1, 'Sucaritra': 1, 'Āhiri': 1, 'Tanarūpi': 1, 'Tillāng': 1, 'Bāgēśrī': 1, 'Cittaranjani': 1, 'Śrī': 1, 'Sārāmati': 1, 'Vasanta': 1, 'Simhēndra madhyamaṁ': 1, 'Janaranjani': 1, 'Hussēnī': 1, 'Nāṭakapriya': 1, 'Sencuruṭṭi': 1, 'Navrōj': 1, 'Gaṁbhīra nāṭa': 1, 'Ranjani': 1, 'Kāmavardani/Pantuvarāḷi': 1, 'Bahudāri': 1, 'Pahāḍi': 1, 'Vāgadīśvari': 1, 'Mandāri': 1, 'Dēvagāndhāri': 1, 'Vakuḷābharaṇaṁ': 1})
# ✅ Scaled training data shape: (184, 60)
# 🏆 Model trained on histogram features.
# 🎵 Enter your .mp3/.wav path:  D:\carnatic\carnatic\13\Sanjay Subrahmanyan - Sri Raghuvara Sugunaalaya.mp3
# 🎧 Top 3 Raga Predictions:
# → Śrīranjani: 15.0%
# → Maṇirangu: 7.0%
# → Navrōj: 6.5%

# %%
import os
import numpy as np
import json
import librosa
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
import warnings

warnings.filterwarnings("ignore")

# ——— 1) HISTOGRAM FEATURE ONLY ———
def extract_hist(base):
    p = base + ".pitch.txt"
    t = base + ".ctonic.txt"
    j = base + ".json"
    if not all(os.path.isfile(f) for f in (p, t, j)):
        return None, None

    try:
        data = np.loadtxt(p)
        freqs = data[:,1]; freqs = freqs[freqs>0]
        tonic = float(open(t).read().strip())
        cents = 1200*np.log2(freqs/tonic)
        cents = cents[~np.isnan(cents)]
        if len(cents)<100: return None, None
        hist, _ = np.histogram(cents, bins=60, range=(-600,1200), density=True)
        meta = json.load(open(j))
        label = meta["raaga"][0]["name"]
        return hist, label
    except:
        return None, None

# ——— 2) LOAD & OVERSAMPLE ———
def load_and_oversample(root):
    X, y = [], []
    for rd, _, files in os.walk(root):
        for fn in files:
            if fn.lower().endswith(".json"):
                base = os.path.join(rd, fn[:-5])
                h,l = extract_hist(base)
                if h is not None:
                    X.append(h); y.append(l)
    X = np.array(X); y = np.array(y)
    print("Before oversample:", Counter(y))

    ros = RandomOverSampler(random_state=42)
    Xr, yr = ros.fit_resample(X, y)
    print(" After oversample:", Counter(yr))
    return Xr, yr

DATA_DIR = "D:/carnatic/carnatic"
X, y = load_and_oversample(DATA_DIR)

# ——— 3) SCALE & TRAIN ———
scaler = StandardScaler()
Xs = scaler.fit_transform(X)

clf = RandomForestClassifier(
    n_estimators=200,
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)
clf.fit(Xs, y)
print("🏆 Trained on oversampled data.")

# ——— 4) PREDICTION (Top‑3) ———
def predict_top3(audio_path):
    y_a, sr = librosa.load(audio_path, sr=None)
    pitches = librosa.yin(y_a,
                          fmin=librosa.note_to_hz("C2"),
                          fmax=librosa.note_to_hz("C7"),
                          sr=sr)
    pitches = pitches[~np.isnan(pitches)]
    if len(pitches)<100:
        print("⚠️ Audio too short/noisy."); return

    h, bins = np.histogram(np.log2(pitches), bins=100)
    tonic = 2**bins[np.argmax(h)]
    cents = 1200*np.log2(pitches/tonic)
    hist, _ = np.histogram(cents, bins=60, range=(-600,1200), density=True)

    f2 = hist.reshape(1,-1)
    f2s = scaler.transform(f2)
    probs = clf.predict_proba(f2s)[0]
    idxs = np.argsort(probs)[-3:][::-1]

    print("\n🎧 Top 3 Raga Predictions:")
    for i in idxs:
        print(f"→ {clf.classes_[i]}: {probs[i]*100:.1f}%")

# ——— 5) RUN ———
path = input("🎵 Path to .mp3/.wav: ").strip()
if os.path.isfile(path):
    predict_top3(path)
else:
    print("❌ File not found.")
# Out:
# Before oversample: Counter({'Rāgamālika': 8, 'Saurāṣtraṁ': 7, 'Tōḍi': 7, 'Kamās': 7, 'Bhairavi': 5, 'Behāg': 5, 'Kalyāṇi': 4, 'Suraṭi': 4, 'Ṣanmukhapriya': 4, 'Rītigauḷa': 4, 'Mōhanaṁ': 4, 'Śankarābharaṇaṁ': 3, 'Bēgaḍa': 3, 'Kāṁbhōji': 3, 'Sāvēri': 3, 'Jōnpuri': 3, 'Sindhubhairavi': 3, 'Harikāmbhōji': 3, 'Kānaḍa': 3, 'Śrīranjani': 2, 'Pūrṇacandrika': 2, 'Madhyamāvati': 2, 'Nādanāmakriya': 2, 'Lalita': 2, 'Nāṭa': 2, 'Kalgaḍa': 2, 'Jaganmōhini': 2, 'Hamīr kaḷyaṇi': 2, 'Pāḍi': 2, 'Amṛtavarṣiṇi': 2, 'Maṇirangu': 2, 'Śuddadhanyāsi': 2, 'Kuntalavarāḷi': 2, 'Kāpi': 2, 'Ābhōgi': 2, 'Karṇāṭaka dēvagāndhāri': 2, 'Kumudakriyā': 2, 'Karaharapriya': 2, 'Gauḷa': 2, 'Mārgahindōḷaṁ': 2, 'Kēdāragauḷa': 2, 'Sahānā': 2, 'Nīlāṁbari': 2, 'Puṇṇāgavarāḷi': 1, 'Kathanakutūhalaṁ': 1, 'Sālaga bhairavi': 1, 'Kalāvati': 1, 'Dvijāvanti': 1, 'Kedāraṁ': 1, 'Cakravākaṁ': 1, 'Sāranga': 1, 'Sarasvatī manōhari': 1, 'Sāma': 1, 'Gamakakriyā': 1, 'Sindhumandāri': 1, 'Dhanyāsi': 1, 'Ānandabhairavi': 1, 'Hindōḷaṁ': 1, 'Rasikapriya': 1, 'Yamuna kalyāṇi': 1, 'Pūrvīkaḷyāṇi': 1, 'Bṛndāvana sāranga': 1, 'Dhanaśrī': 1, 'Hamsadhvani': 1, 'Śudda sāvēri': 1, 'Latāngi': 1, 'Lalita pancamaṁ': 1, 'Varāḷi': 1, 'Bhūṣāvaḷi': 1, 'Dēś': 1, 'Haṁsānandi': 1, 'Mānḍu': 1, 'Sucaritra': 1, 'Āhiri': 1, 'Tanarūpi': 1, 'Tillāng': 1, 'Bāgēśrī': 1, 'Cittaranjani': 1, 'Śrī': 1, 'Sārāmati': 1, 'Vasanta': 1, 'Simhēndra madhyamaṁ': 1, 'Janaranjani': 1, 'Hussēnī': 1, 'Nāṭakapriya': 1, 'Sencuruṭṭi': 1, 'Navrōj': 1, 'Gaṁbhīra nāṭa': 1, 'Ranjani': 1, 'Kāmavardani/Pantuvarāḷi': 1, 'Bahudāri': 1, 'Pahāḍi': 1, 'Vāgadīśvari': 1, 'Mandāri': 1, 'Dēvagāndhāri': 1, 'Vakuḷābharaṇaṁ': 1})
#  After oversample: Counter({'Śrīranjani': 8, 'Śankarābharaṇaṁ': 8, 'Pūrṇacandrika': 8, 'Kalyāṇi': 8, 'Madhyamāvati': 8, 'Puṇṇāgavarāḷi': 8, 'Nādanāmakriya': 8, 'Kathanakutūhalaṁ': 8, 'Lalita': 8, 'Suraṭi': 8, 'Sālaga bhairavi': 8, 'Ṣanmukhapriya': 8, 'Kalāvati': 8, 'Rāgamālika': 8, 'Dvijāvanti': 8, 'Saurāṣtraṁ': 8, 'Kedāraṁ': 8, 'Cakravākaṁ': 8, 'Bēgaḍa': 8, 'Sāranga': 8, 'Sarasvatī manōhari': 8, 'Kāṁbhōji': 8, 'Tōḍi': 8, 'Sāvēri': 8, 'Nāṭa': 8, 'Sāma': 8, 'Gamakakriyā': 8, 'Kalgaḍa': 8, 'Bhairavi': 8, 'Jōnpuri': 8, 'Rītigauḷa': 8, 'Jaganmōhini': 8, 'Sindhumandāri': 8, 'Dhanyāsi': 8, 'Hamīr kaḷyaṇi': 8, 'Pāḍi': 8, 'Mōhanaṁ': 8, 'Sindhubhairavi': 8, 'Kamās': 8, 'Ānandabhairavi': 8, 'Amṛtavarṣiṇi': 8, 'Hindōḷaṁ': 8, 'Maṇirangu': 8, 'Śuddadhanyāsi': 8, 'Rasikapriya': 8, 'Yamuna kalyāṇi': 8, 'Pūrvīkaḷyāṇi': 8, 'Harikāmbhōji': 8, 'Bṛndāvana sāranga': 8, 'Kuntalavarāḷi': 8, 'Kāpi': 8, 'Dhanaśrī': 8, 'Hamsadhvani': 8, 'Śudda sāvēri': 8, 'Latāngi': 8, 'Lalita pancamaṁ': 8, 'Ābhōgi': 8, 'Varāḷi': 8, 'Bhūṣāvaḷi': 8, 'Behāg': 8, 'Dēś': 8, 'Haṁsānandi': 8, 'Kānaḍa': 8, 'Karṇāṭaka dēvagāndhāri': 8, 'Kumudakriyā': 8, 'Karaharapriya': 8, 'Mānḍu': 8, 'Sucaritra': 8, 'Gauḷa': 8, 'Āhiri': 8, 'Tanarūpi': 8, 'Mārgahindōḷaṁ': 8, 'Tillāng': 8, 'Bāgēśrī': 8, 'Cittaranjani': 8, 'Kēdāragauḷa': 8, 'Sahānā': 8, 'Śrī': 8, 'Sārāmati': 8, 'Vasanta': 8, 'Simhēndra madhyamaṁ': 8, 'Janaranjani': 8, 'Hussēnī': 8, 'Nāṭakapriya': 8, 'Nīlāṁbari': 8, 'Sencuruṭṭi': 8, 'Navrōj': 8, 'Gaṁbhīra nāṭa': 8, 'Ranjani': 8, 'Kāmavardani/Pantuvarāḷi': 8, 'Bahudāri': 8, 'Pahāḍi': 8, 'Vāgadīśvari': 8, 'Mandāri': 8, 'Dēvagāndhāri': 8, 'Vakuḷābharaṇaṁ': 8})
# 🏆 Trained on oversampled data.
# 🎵 Path to .mp3/.wav:  D:\carnatic\carnatic\9\Sanjay Subrahmanyan - Eranapai.mp3
# 🎧 Top 3 Raga Predictions:
# → Janaranjani: 7.5%
# → Harikāmbhōji: 7.0%
# → Kalāvati: 7.0%

# %%
import os
import numpy as np
import json
import librosa
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
from scipy.stats import gaussian_kde
import warnings

warnings.filterwarnings("ignore")

# ——— 1) DATASET FILE CHECKER ———
def check_dataset_files(root):
    print("🔍 Checking dataset integrity...\n")
    missing = []
    total = 0
    for rd, _, files in os.walk(root):
        json_files = [f for f in files if f.endswith(".json")]
        for fn in json_files:
            base = os.path.join(rd, fn[:-5])
            required = [base + ext for ext in [".json", ".pitch.txt", ".ctonic.txt", ".mp3"]]
            missing_parts = [os.path.basename(f) for f in required if not os.path.isfile(f)]
            if missing_parts:
                missing.append((os.path.basename(base), missing_parts))
            total += 1

    print(f"📦 Total samples checked: {total}")
    print(f"❌ Incomplete samples: {len(missing)}\n")
    for name, parts in missing:
        print(f" - {name} missing: {', '.join(parts)}")
    if not missing:
        print("✅ All samples are complete!")
    print("-" * 50)

# ——— 2) FEATURE EXTRACTION (.mp3 support) ———
def extract_features(base):
    p = base + ".pitch.txt"
    t = base + ".ctonic.txt"
    j = base + ".json"
    a = base + ".mp3"  # .mp3 instead of .wav

    if not all(os.path.isfile(f) for f in (p, t, j, a)):
        return None, None

    try:
        # Pitch histogram
        data = np.loadtxt(p)
        freqs = data[:, 1]
        freqs = freqs[freqs > 0]
        tonic = float(open(t).read().strip())
        cents = 1200 * np.log2(freqs / tonic)
        cents = cents[~np.isnan(cents)]
        if len(cents) < 100:
            return None, None
        hist, _ = np.histogram(cents, bins=120, range=(-300, 900), density=True)

        # MFCC and Chroma from .mp3
        y, sr = librosa.load(a, sr=None)
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
        chroma = librosa.feature.chroma_stft(y=y, sr=sr)

        mfcc_mean = np.mean(mfcc, axis=1)
        mfcc_std = np.std(mfcc, axis=1)
        chroma_mean = np.mean(chroma, axis=1)

        features = np.concatenate([hist, mfcc_mean, mfcc_std, chroma_mean])
        meta = json.load(open(j))
        label = meta["raaga"][0]["name"]

        return features, label
    except Exception as e:
        print("⚠️ Error in", base, ":", e)
        return None, None

# ——— 3) LOAD & OVERSAMPLE ———
def load_and_oversample(root):
    X, y = [], []
    for rd, _, files in os.walk(root):
        for fn in files:
            if fn.lower().endswith(".json"):
                base = os.path.join(rd, fn[:-5])
                f, l = extract_features(base)
                if f is not None:
                    X.append(f)
                    y.append(l)
    X = np.array(X)
    y = np.array(y)
    print("✅ Valid samples loaded:", len(X))

    if len(X) == 0:
        raise ValueError("❌ No valid data found. Check dataset integrity.")

    print("Before oversample:", Counter(y))
    ros = RandomOverSampler(random_state=42)
    Xr, yr = ros.fit_resample(X, y)
    print(" After oversample:", Counter(yr))
    return Xr, yr

# ——— 4) TRAIN THE CLASSIFIER ———
def train_model(data_dir):
    check_dataset_files(data_dir)
    X, y = load_and_oversample(data_dir)

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    clf = RandomForestClassifier(
        n_estimators=200,
        class_weight='balanced',
        random_state=42,
        n_jobs=-1
    )
    clf.fit(X_scaled, y)
    print("🏆 Model trained successfully.\n")
    return clf, scaler

# ——— 5) PREDICT TOP‑3 ———
def predict_top3(audio_path, clf, scaler):
    y_a, sr = librosa.load(audio_path, sr=None)

    # Tonic estimation using KDE
    pitches = librosa.yin(y_a,
                          fmin=librosa.note_to_hz("C2"),
                          fmax=librosa.note_to_hz("C7"),
                          sr=sr)
    pitches = pitches[~np.isnan(pitches)]
    if len(pitches) < 100:
        print("⚠️ Audio too short or noisy.")
        return

    log_pitches = np.log2(pitches)
    kde = gaussian_kde(log_pitches)
    x_vals = np.linspace(np.min(log_pitches), np.max(log_pitches), 1000)
    tonic_log = x_vals[np.argmax(kde(x_vals))]
    tonic = 2 ** tonic_log

    cents = 1200 * np.log2(pitches / tonic)
    hist, _ = np.histogram(cents, bins=120, range=(-300, 900), density=True)

    # MFCC + Chroma from .mp3
    mfcc = librosa.feature.mfcc(y=y_a, sr=sr, n_mfcc=13)
    chroma = librosa.feature.chroma_stft(y=y_a, sr=sr)
    mfcc_mean = np.mean(mfcc, axis=1)
    mfcc_std = np.std(mfcc, axis=1)
    chroma_mean = np.mean(chroma, axis=1)

    features = np.concatenate([hist, mfcc_mean, mfcc_std, chroma_mean])
    features_scaled = scaler.transform([features])
    probs = clf.predict_proba(features_scaled)[0]
    idxs = np.argsort(probs)[-3:][::-1]

    print("\n🎧 Top 3 Raga Predictions:")
    for i in idxs:
        print(f"→ {clf.classes_[i]}: {probs[i] * 100:.1f}%")

# ——— 6) MAIN SCRIPT ———
if __name__ == "__main__":
    DATA_DIR = "D:/carnatic/carnatic"  # 🔁 Change to your dataset path

    # Train model
    clf, scaler = train_model(DATA_DIR)

    # Predict from an MP3 file
    test_path = input("\n🎵 Enter path to test .mp3: ").strip()
    if os.path.isfile(test_path):
        predict_top3(test_path, clf, scaler)
    else:
        print("❌ File not found.")
# Out:
# 🔍 Checking dataset integrity...
#
# 📦 Total samples checked: 197
# ❌ Incomplete samples: 0
#
# ✅ All samples are complete!
# --------------------------------------------------
# ⚠️ Error in D:/carnatic/carnatic\0\Cherthala Ranganatha Sharma - Varashiki Vahana : list index out of range
# ⚠️ Error in D:/carnatic/carnatic\111\Mahati - Gopi Gopala Bala : list index out of range
# ⚠️ Error in D:/carnatic/carnatic\141\Chaitra Sairam - Ardhanareeshwaram : list index out of range
# ⚠️ Error in D:/carnatic/carnatic\146\Chaitra Sairam - Gange Maampahi : list index out of range
# ⚠️ Error in D:/carnatic/carnatic\152\Kuldeep Pai - Gange Maam Pahi : list index out of range
# ⚠️ Error in D:/carnatic/carnatic\154\Kuldeep Pai - Vasudeva Sutam Devam : list index out of range

# %%
import os

def check_dataset_files(root):
    print("🔍 Checking dataset integrity...\n")
    missing = []
    total = 0
    for rd, _, files in os.walk(root):
        json_files = [f for f in files if f.lower().endswith(".json")]
        for fn in json_files:
            total += 1
            base = os.path.join(rd, fn[:-5])  # remove .json extension
            required = [base + ext for ext in [".json", ".pitch.txt", ".ctonic.txt", ".wav"]]
            missing_parts = [os.path.basename(f) for f in required if not os.path.isfile(f)]
            if missing_parts:
                missing.append((os.path.basename(base), missing_parts))

    print(f"📦 Total samples checked: {total}")
    print(f"❌ Incomplete samples found: {len(missing)}\n")

    for name, parts in missing:
        print(f" - {name} missing: {', '.join(parts)}")

    if not missing:
        print("✅ All samples have required files!")
    print("-" * 50)

# Replace this with your path
DATA_DIR = "D:/carnatic/carnatic"
check_dataset_files(DATA_DIR)
# Out:
# 🔍 Checking dataset integrity...
#
# 📦 Total samples checked: 197
# ❌ Incomplete samples found: 197
#
#  - Cherthala Ranganatha Sharma - Varashiki Vahana missing: Cherthala Ranganatha Sharma - Varashiki Vahana.wav
#  - Cherthala Ranganatha Sharma - Bhuvini Dasudane missing: Cherthala Ranganatha Sharma - Bhuvini Dasudane.wav
#  - Sanjay Subrahmanyan - Pullum Silambena Kan missing: Sanjay Subrahmanyan - Pullum Silambena Kan.wav
#  - Modhumudi Sudhakar - Telisi Rama missing: Modhumudi Sudhakar - Telisi Rama.wav
#  - Modhumudi Sudhakar - Sundari Nee Divya missing: Modhumudi Sudhakar - Sundari Nee Divya.wav
#  - Modhumudi Sudhakar - Rama Namam Bhajare missing: Modhumudi Sudhakar - Rama Namam Bhajare.wav
#  - Modhumudi Sudhakar - Ghandhamu Poyyaruga missing: Modhumudi Sudhakar - Ghandhamu Poyyaruga.wav
#  - Modhumudi Sudhakar - Mangalam Avanisutanatha missing: Modhumudi Sudhakar - Mangalam Avanisutanatha.wav
#  - Mahati - Sharanagatha Vatsale missing: Mahati - Sharanagatha Vatsale.wav
#  - Mahati - Hiranmayeem missing: Mahati - Hiranmayeem.wav
#  - Mahati - Kannallavo Swami missing: Mahati - Kannallavo Swami.wav
#  - Mahati - Padavini missing: Mahati - Padavini.wav
#  - Mahati - Ragam Tanam Pallavi missing: Mahati - Ragam Tanam Pallavi.wav
#  - Sanjay Subrahmanyan - Ennadu Jootuno missing: Sanjay Subrahmanyan - Ennadu Jootuno.wav
#  - Mahati - Vandu Ketpaar Illayo missing: Mahati - Vandu Ketpaar Illayo.wav
#  - Mahati - Gopi Gopala Bala missing: Mahati - Gopi Gopala Bala.wav
#  - Mahati - Chinnanchiru Kiliye missing: Mahati - Chinnanchiru Kiliye.wav
#  - Mahati - Tillana missing: Mahati - Tillana.wav
#  - Mahati - Pavamana Suttudu Pattu missing: Mahati - Pavamana Suttudu Pattu.wav
#  - Kanakadurga Venkatesh - Rama Neepai missing: Kanakadurga Venkatesh - Rama Neepai.wav
#  - Kanakadurga Venkatesh - Etulabrotuva missing: Kanakadurga Venkatesh - Etulabrotuva.wav
#  - Kanakadurga Venkatesh - Lokavana Chatura missing: Kanakadurga Venkatesh - Lokavana Chatura.wav
#  - Kanakadurga Venkatesh - Neevada Negana missing: Kanakadurga Venkatesh - Neevada Negana.wav
#  - Kanakadurga Venkatesh - Enthavedukonthu Raghava missing: Kanakadurga Venkatesh - Enthavedukonthu Raghava.wav
#  - Sanjay Subrahmanyan - Aru marundu missing: Sanjay Subrahmanyan - Aru marundu.wav
#  - Kanakadurga Venkatesh - Koluvamaregatha missing: Kanakadurga Venkatesh - Koluvamaregatha.wav
#  - Kanakadurga Venkatesh - Vara Leela Gana Lola missing: Kanakadurga Venkatesh - Vara Leela Gana Lola.wav
#  - Srividya Janakiraman - Sarasuda Ninne Kori missing: Srividya Janakiraman - Sarasuda Ninne Kori.wav
#  - Srividya Janakiraman - Jaya Jaya Janaki Kantha missing: Srividya Janakiraman - Jaya Jaya Janaki Kantha.wav
#  - Srividya Janakiraman - Santhamu leka Sowkyamu ledu missing: Srividya Janakiraman - Santhamu leka Sowkyamu ledu.wav
#  - Srividya Janakiraman - Sri Dundurge Siva Samsaare missing: Srividya Janakiraman - Sri Dundurge Siva Samsaare.wav
#  - Srividya Janakiraman - Gnanamosaga Rada missing: Srividya Janakiraman - Gnanamosaga Rada.wav
#  - Srividya Janakiraman - Parvathi Ninu Ne Nera Nammithi missing: Srividya Janakiraman - Parvathi Ninu Ne Nera Nammithi.wav
#  - Srividya Janakiraman - Nee Sari evvaramma missing: Srividya Janakiraman - Nee Sari evvaramma.wav
#  - Srividya Janakiraman - Nenindal Agaadadu undo missing: Srividya Janakiraman - Nenindal Agaadadu undo.wav
#  - Sanjay Subrahmanyan - Sri Raghuvara Sugunaalaya missing: Sanjay Subrahmanyan - Sri Raghuvara Sugunaalaya.wav
#  - Sumithra Vasudev - Vanajaksha Ninne Kori missing: Sumithra Vasudev - Vanajaksha Ninne Kori.wav
#  - Sumithra Vasudev - Sri Vidhya Rajagopala missing: Sumithra Vasudev - Sri Vidhya Rajagopala.wav
#  - Sumithra Vasudev - Karuninchutakidi missing: Sumithra Vasudev - Karuninchutakidi.wav
#  - Sumithra Vasudev - Ramabhi Rama Manasu missing: Sumithra Vasudev - Ramabhi Rama Manasu.wav
#  - Sumithra Vasudev - Thoomani Madatthu missing: Sumithra Vasudev - Thoomani Madatthu.wav
#  - Sumithra Vasudev - Sri Guru Na Palitosmi missing: Sumithra Vasudev - Sri Guru Na Palitosmi.wav
#  - Sumithra Vasudev - Mati Matiki missing: Sumithra Vasudev - Mati Matiki.wav
#  - Sumithra Vasudev - Aaniraimekkani missing: Sumithra Vasudev - Aaniraimekkani.wav
#  - Sumithra Vasudev - Va Va Brindavana missing: Sumithra Vasudev - Va Va Brindavana.wav
#  - Sumithra Vasudev - Mangalam Kosalendraya missing: Sumithra Vasudev - Mangalam Kosalendraya.wav
#  - Sanjay Subrahmanyan - Sarasadalanayana missing: Sanjay Subrahmanyan - Sarasadalanayana.wav
#  - Chaitra Sairam - Rakta Ganapatim missing: Chaitra Sairam - Rakta Ganapatim.wav
#  - Chaitra Sairam - Ardhanareeshwaram missing: Chaitra Sairam - Ardhanareeshwaram.wav
#  - Chaitra Sairam - Kamalamba Samrakshatu missing: Chaitra Sairam - Kamalamba Samrakshatu.wav
#  - Chaitra Sairam - Anandaamrutakarshini missing: Chaitra Sairam - Anandaamrutakarshini.wav
#  - Chaitra Sairam - Govardhana Girisham missing: Chaitra Sairam - Govardhana Girisham.wav
#  - Chaitra Sairam - Shri Subramanyaya Namaste missing: Chaitra Sairam - Shri Subramanyaya Namaste.wav
#  - Chaitra Sairam - Gange Maampahi missing: Chaitra Sairam - Gange Maampahi.wav
#  - Chaitra Sairam - Mamava Pattabhi Rama missing: Chaitra Sairam - Mamava Pattabhi Rama.wav
#  - Kuldeep Pai - Kari Kalabha Mukham missing: Kuldeep Pai - Kari Kalabha Mukham.wav
#  - Kuldeep Pai - Kaalaharanamelara missing: Kuldeep Pai - Kaalaharanamelara.wav
#  - Sanjay Subrahmanyan - Paarengum missing: Sanjay Subrahmanyan - Paarengum.wav
#  - Kuldeep Pai - Brochevarevarura missing: Kuldeep Pai - Brochevarevarura.wav
#  - Kuldeep Pai - Arul Seya Vendum Ayya missing: Kuldeep Pai - Arul Seya Vendum Ayya.wav
#  - Kuldeep Pai - Gange Maam Pahi missing: Kuldeep Pai - Gange Maam Pahi.wav
#  - Kuldeep Pai - Thappi Bratikipova missing: Kuldeep Pai - Thappi Bratikipova.wav
#  - Kuldeep Pai - Vasudeva Sutam Devam missing: Kuldeep Pai - Vasudeva Sutam Devam.wav
#  - Kuldeep Pai - Krishna Nee Begane Baaro missing: Kuldeep Pai - Krishna Nee Begane Baaro.wav
#  - Sanjay Subrahmanyan - Undan Paada Pankayam missing: Sanjay Subrahmanyan - Undan Paada Pankayam.wav
#  - Sanjay Subrahmanyan - Shatre Vilagi Irum missing: Sanjay Subrahmanyan - Shatre Vilagi Irum.wav
#  - Sanjay Subrahmanyan - Kamakshi missing: Sanjay Subrahmanyan - Kamakshi.wav
#  - Sanjay Subrahmanyan - Entara Nitana missing: Sanjay Subrahmanyan - Entara Nitana.wav
#  - Sanjay Subrahmanyan - Ragam Thanam Pallavi - Shanmukhapriya missing: Sanjay Subrahmanyan - Ragam Thanam Pallavi - Shanmukhapriya.wav
#  - Sanjay Subrahmanyan - Soundararajam missing: Sanjay Subrahmanyan - Soundararajam.wav
#  - Sanjay Subrahmanyan - Ozhukkam Uyirinum missing: Sanjay Subrahmanyan - Ozhukkam Uyirinum.wav
#  - Sanjay Subrahmanyan - Raagam Thaanam Pallavi missing: Sanjay Subrahmanyan - Raagam Thaanam Pallavi.wav
#  - Sanjay Subrahmanyan - Maname Ramanai Paada missing: Sanjay Subrahmanyan - Maname Ramanai Paada.wav
#  - Sanjay Subrahmanyan - Teerthakarayinile missing: Sanjay Subrahmanyan - Teerthakarayinile.wav
#  - Sanjay Subrahmanyan - Payum Oli Nee Yenakku missing: Sanjay Subrahmanyan - Payum Oli Nee Yenakku.wav
#  - Sanjay Subrahmanyan - Thillana Dhanashri missing: Sanjay Subrahmanyan - Thillana Dhanashri.wav
#  - Sanjay Subrahmanyan - Pavamana Suthudu missing: Sanjay Subrahmanyan - Pavamana Suthudu.wav
#  - Ashwath Narayanan - Sadabalarupapi Shlokam missing: Ashwath Narayanan - Sadabalarupapi Shlokam.wav
#  - Ashwath Narayanan - Eranapai missing: Ashwath Narayanan - Eranapai.wav
#  - Sanjay Subrahmanyan - Saravanabhava Enum missing: Sanjay Subrahmanyan - Saravanabhava Enum.wav
#  - Ashwath Narayanan - Samajavarada missing: Ashwath Narayanan - Samajavarada.wav
#  - Ashwath Narayanan - Aparadhamula missing: Ashwath Narayanan - Aparadhamula.wav
#  - Ashwath Narayanan - Angakaram missing: Ashwath Narayanan - Angakaram.wav
#  - Ashwath Narayanan - Parama Purusham missing: Ashwath Narayanan - Parama Purusham.wav
#  - Ashwath Narayanan - Evarura missing: Ashwath Narayanan - Evarura.wav
#  - Ashwath Narayanan - Marubari missing: Ashwath Narayanan - Marubari.wav
#  - Ashwath Narayanan - Thillana Purnachandrika missing: Ashwath Narayanan - Thillana Purnachandrika.wav
#  - Vignesh Ishwar - Evvari Bodhana missing: Vignesh Ishwar - Evvari Bodhana.wav
#  - Vignesh Ishwar - Karuna Ela Gante missing: Vignesh Ishwar - Karuna Ela Gante.wav
#  - Vignesh Ishwar - Lokavana Chatura missing: Vignesh Ishwar - Lokavana Chatura.wav
#  - Sanjay Subrahmanyan - Karuvutranaal Mudalaaga missing: Sanjay Subrahmanyan - Karuvutranaal Mudalaaga.wav
#  - Vignesh Ishwar - Hiranmayeem Lakshmeem missing: Vignesh Ishwar - Hiranmayeem Lakshmeem.wav
#  - Vignesh Ishwar - Gopanandana missing: Vignesh Ishwar - Gopanandana.wav
#  - Vignesh Ishwar - Amba Kamakshi missing: Vignesh Ishwar - Amba Kamakshi.wav
#  - Vignesh Ishwar - Sanchara Dhadhara missing: Vignesh Ishwar - Sanchara Dhadhara.wav
#  - Vignesh Ishwar - Idhuthaano Thillai Sthalam missing: Vignesh Ishwar - Idhuthaano Thillai Sthalam.wav
#  - Vignesh Ishwar - Vitthala Salaho Swamy missing: Vignesh Ishwar - Vitthala Salaho Swamy.wav
#  - Vignesh Ishwar - Niraimadi Mugam Thiruppugazh missing: Vignesh Ishwar - Niraimadi Mugam Thiruppugazh.wav
#  - Vignesh Ishwar - Pavamana Suthudu Mangalam missing: Vignesh Ishwar - Pavamana Suthudu Mangalam.wav
#  - V. Shankaranarayanan - Shloka missing: V. Shankaranarayanan - Shloka.wav
#  - V. Shankaranarayanan - Nera Nammiti missing: V. Shankaranarayanan - Nera Nammiti.wav
#  - Sanjay Subrahmanyan - Maname Kanamum missing: Sanjay Subrahmanyan - Maname Kanamum.wav
#  - V. Shankaranarayanan - Ninne Bhajana missing: V. Shankaranarayanan - Ninne Bhajana.wav
#  - V. Shankaranarayanan - Dinamani Vamsa missing: V. Shankaranarayanan - Dinamani Vamsa.wav
#  - V. Shankaranarayanan - Ardhanareeshwaram missing: V. Shankaranarayanan - Ardhanareeshwaram.wav
#  - V. Shankaranarayanan - Chakkani Raja missing: V. Shankaranarayanan - Chakkani Raja.wav
#  - V. Shankaranarayanan - Chenduril Nindradum Kanda missing: V. Shankaranarayanan - Chenduril Nindradum Kanda.wav
#  - V. Shankaranarayanan - Muruga Muruga Muruga missing: V. Shankaranarayanan - Muruga Muruga Muruga.wav
#  - V. Shankaranarayanan - Pavamana Suthudu Pattu missing: V. Shankaranarayanan - Pavamana Suthudu Pattu.wav
#  - Cherthala Ranganatha Sharma - Velum Mayilume missing: Cherthala Ranganatha Sharma - Velum Mayilume.wav
#  - Sanjay Subrahmanyan - Pavamaana Suthudu Pattu missing: Sanjay Subrahmanyan - Pavamaana Suthudu Pattu.wav
#  - Sanjay Subrahmanyan - Vanajakshi - Varnam missing: Sanjay Subrahmanyan - Vanajakshi - Varnam.wav
#  - Sanjay Subrahmanyan - Sama geeta priyan missing: Sanjay Subrahmanyan - Sama geeta priyan.wav
#  - Sanjay Subrahmanyan - Nadopasana missing: Sanjay Subrahmanyan - Nadopasana.wav
#  - Sanjay Subrahmanyan - Janani missing: Sanjay Subrahmanyan - Janani.wav
#  - Sanjay Subrahmanyan - Deenarakshaka missing: Sanjay Subrahmanyan - Deenarakshaka.wav
#  - Sanjay Subrahmanyan - Va vela va missing: Sanjay Subrahmanyan - Va vela va.wav
#  - Sanjay Subrahmanyan - Chalamelara Saketha Rama missing: Sanjay Subrahmanyan - Chalamelara Saketha Rama.wav
#  - Sanjay Subrahmanyan - O Rangashayee missing: Sanjay Subrahmanyan - O Rangashayee.wav
#  - Sanjay Subrahmanyan - Ganta mani aadudhu missing: Sanjay Subrahmanyan - Ganta mani aadudhu.wav
#  - Cherthala Ranganatha Sharma - Karuna Nidhi Illalo missing: Cherthala Ranganatha Sharma - Karuna Nidhi Illalo.wav
#  - Sanjay Subrahmanyan - Uppum karpuramum missing: Sanjay Subrahmanyan - Uppum karpuramum.wav
#  - Sanjay Subrahmanyan - Innamum Oru thalam missing: Sanjay Subrahmanyan - Innamum Oru thalam.wav
#  - Sanjay Subrahmanyan - Oorilen Kaani Illai missing: Sanjay Subrahmanyan - Oorilen Kaani Illai.wav
#  - Sanjay Subrahmanyan - Karupuram Naarumo missing: Sanjay Subrahmanyan - Karupuram Naarumo.wav
#  - Sanjay Subrahmanyan - Ramakrishnaru Manaegae missing: Sanjay Subrahmanyan - Ramakrishnaru Manaegae.wav
#  - Sanjay Subrahmanyan - Teerthakarayinile missing: Sanjay Subrahmanyan - Teerthakarayinile.wav
#  - Sanjay Subrahmanyan - Ninnaiye rathi missing: Sanjay Subrahmanyan - Ninnaiye rathi.wav
#  - Sanjay Subrahmanyan - Kalilo Hari Smrana missing: Sanjay Subrahmanyan - Kalilo Hari Smrana.wav
#  - Sanjay Subrahmanyan - Mangalam missing: Sanjay Subrahmanyan - Mangalam.wav
#  - KP Nandini - Nadatanum Anisham missing: KP Nandini - Nadatanum Anisham.wav
#  - Cherthala Ranganatha Sharma - Tulasi Bilva missing: Cherthala Ranganatha Sharma - Tulasi Bilva.wav
#  - Rithvik Raja - Karunimpa Idi missing: Rithvik Raja - Karunimpa Idi.wav
#  - Rithvik Raja - Endaro Mahanubhavulu missing: Rithvik Raja - Endaro Mahanubhavulu.wav
#  - S Sundar - Vanajaksha Ninne Nammiti missing: S Sundar - Vanajaksha Ninne Nammiti.wav
#  - S Sundar - Parvathi Ninnu Neranammiti missing: S Sundar - Parvathi Ninnu Neranammiti.wav
#  - KP Nandini - Ardhanarishwaram missing: KP Nandini - Ardhanarishwaram.wav
#  - KP Nandini - Bhavamulona missing: KP Nandini - Bhavamulona.wav
#  - KP Nandini - Manasaramathi missing: KP Nandini - Manasaramathi.wav
#  - KP Nandini - Seethamma missing: KP Nandini - Seethamma.wav
#  - KP Nandini - Janakipathe Jaya Karunya Jaladhe missing: KP Nandini - Janakipathe Jaya Karunya Jaladhe.wav
#  - KP Nandini - Eppadi Padinaro missing: KP Nandini - Eppadi Padinaro.wav
#  - Cherthala Ranganatha Sharma - Rama Rama Guna Seema missing: Cherthala Ranganatha Sharma - Rama Rama Guna Seema.wav
#  - KP Nandini - Tillana missing: KP Nandini - Tillana.wav
#  - S Sundar - Nannu Brova Neeku missing: S Sundar - Nannu Brova Neeku.wav
#  - S Sundar - Paahi Maam Sri missing: S Sundar - Paahi Maam Sri.wav
#  - S Sundar - Eppadi Manam Thunindhadho missing: S Sundar - Eppadi Manam Thunindhadho.wav
#  - S Sundar - Sudhaamayee missing: S Sundar - Sudhaamayee.wav
#  - S Sundar - Jaya Jaya Padmanabhanujese missing: S Sundar - Jaya Jaya Padmanabhanujese.wav
#  - S Sundar - Enadhu Manam Kavalai missing: S Sundar - Enadhu Manam Kavalai.wav
#  - S Sundar - Purahara Nandana missing: S Sundar - Purahara Nandana.wav
#  - S Sundar - Geetha Vaadya Natana missing: S Sundar - Geetha Vaadya Natana.wav
#  - S Sundar - Shloka Namaste Sarvalokana missing: S Sundar - Shloka Namaste Sarvalokana.wav
#  - Cherthala Ranganatha Sharma - Prathi Vaaram Vaaram missing: Cherthala Ranganatha Sharma - Prathi Vaaram Vaaram.wav
#  - S Sundar - Nera Nammiti missing: S Sundar - Nera Nammiti.wav
#  - S Sundar - Kannanai Paadu Maname missing: S Sundar - Kannanai Paadu Maname.wav
#  - S Sundar - Devadi Devanukku Jaya Mangalam missing: S Sundar - Devadi Devanukku Jaya Mangalam.wav
#  - Rithvik Raja - Chintayama Kanda missing: Rithvik Raja - Chintayama Kanda.wav
#  - Rithvik Raja - Seetapati Namanasuna missing: Rithvik Raja - Seetapati Namanasuna.wav
#  - Rithvik Raja - Emani Migula missing: Rithvik Raja - Emani Migula.wav
#  - Rithvik Raja - Bhogeendra Shayinam missing: Rithvik Raja - Bhogeendra Shayinam.wav
#  - Rithvik Raja - Saraguna Palimpa missing: Rithvik Raja - Saraguna Palimpa.wav
#  - Rithvik Raja - Madhava Mamava missing: Rithvik Raja - Madhava Mamava.wav
#  - Rithvik Raja - Sapasyat Kausalya missing: Rithvik Raja - Sapasyat Kausalya.wav
#  - Cherthala Ranganatha Sharma - Idhu Thaano Thillai Sthalam missing: Cherthala Ranganatha Sharma - Idhu Thaano Thillai Sthalam.wav
#  - Rithvik Raja - Thillana Senchurutti missing: Rithvik Raja - Thillana Senchurutti.wav
#  - Rithvik Raja - Ramachandraya Mangalam missing: Rithvik Raja - Ramachandraya Mangalam.wav
#  - Vasundara Rajagopal - Sri Jalandara missing: Vasundara Rajagopal - Sri Jalandara.wav
#  - Vasundara Rajagopal - Chandrashekharam Sada Bhajeham missing: Vasundara Rajagopal - Chandrashekharam Sada Bhajeham.wav
#  - Vasundara Rajagopal - Ninnuvina Marigalada missing: Vasundara Rajagopal - Ninnuvina Marigalada.wav
#  - Vasundara Rajagopal - Pranamamyaham Sri Prananatham missing: Vasundara Rajagopal - Pranamamyaham Sri Prananatham.wav
#  - Vasundara Rajagopal - Amba Nilambari missing: Vasundara Rajagopal - Amba Nilambari.wav
#  - Vasundara Rajagopal - Munnu Ravana missing: Vasundara Rajagopal - Munnu Ravana.wav
#  - Vasundara Rajagopal - Shlokham missing: Vasundara Rajagopal - Shlokham.wav
#  - Vasundara Rajagopal - Ni Ninaindhal Aagadhadhu missing: Vasundara Rajagopal - Ni Ninaindhal Aagadhadhu.wav
#  - Cherthala Ranganatha Sharma - Shlokam - Shivah Shaktyayukto missing: Cherthala Ranganatha Sharma - Shlokam - Shivah Shaktyayukto.wav
#  - Vasundara Rajagopal - Avani Sutha missing: Vasundara Rajagopal - Avani Sutha.wav
#  - Akkarai Sisters - Karunimpa Idi missing: Akkarai Sisters - Karunimpa Idi.wav
#  - Akkarai Sisters - Siddhi Vinayakam missing: Akkarai Sisters - Siddhi Vinayakam.wav
#  - Akkarai Sisters - Koti Janmani missing: Akkarai Sisters - Koti Janmani.wav
#  - Akkarai Sisters - Apparama Bhakti missing: Akkarai Sisters - Apparama Bhakti.wav
#  - Akkarai Sisters - Brova Barama missing: Akkarai Sisters - Brova Barama.wav
#  - Akkarai Sisters - Shankari Shankuru missing: Akkarai Sisters - Shankari Shankuru.wav
#  - Akkarai Sisters - Geeta Nayakan missing: Akkarai Sisters - Geeta Nayakan.wav
#  - Akkarai Sisters - Manadirkkugandhadu missing: Akkarai Sisters - Manadirkkugandhadu.wav
#  - Akkarai Sisters - Thillana Pahadi missing: Akkarai Sisters - Thillana Pahadi.wav
#  - Sanjay Subrahmanyan - Eranapai missing: Sanjay Subrahmanyan - Eranapai.wav
#  - Akkarai Sisters - Pavamana Suthudu Mangalam missing: Akkarai Sisters - Pavamana Suthudu Mangalam.wav
#  - Modhumudi Sudhakar - Giriraja Suta missing: Modhumudi Sudhakar - Giriraja Suta.wav
#  - Modhumudi Sudhakar - Dudukugala missing: Modhumudi Sudhakar - Dudukugala.wav
#  - Modhumudi Sudhakar - Edari Sancharintura missing: Modhumudi Sudhakar - Edari Sancharintura.wav
#  - Modhumudi Sudhakar - Shobillu Saptasvara missing: Modhumudi Sudhakar - Shobillu Saptasvara.wav
#  - Modhumudi Sudhakar - Paramatmudu missing: Modhumudi Sudhakar - Paramatmudu.wav
#  - Modhumudi Sudhakar - Paraloka Bhaya missing: Modhumudi Sudhakar - Paraloka Bhaya.wav
#  - Modhumudi Sudhakar - Entha Muddo missing: Modhumudi Sudhakar - Entha Muddo.wav
#  - Modhumudi Sudhakar - Koluvaiyunnade missing: Modhumudi Sudhakar - Koluvaiyunnade.wav
#  - Modhumudi Sudhakar - Eramuni missing: Modhumudi Sudhakar - Eramuni.wav
# --------------------------------------------------
